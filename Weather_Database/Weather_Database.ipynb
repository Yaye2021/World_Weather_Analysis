# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 740

# %%
# Import the requests library.
import requests

# %%
# Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
    # Parse the JSON and retrieve data.
            city_weather = requests.get(city_url).json()
            # Parse out the needed data.
            city_country = city_weather["sys"]["country"]
            city_lat = city_weather["coord"]["lat"]
            city_lng = city_weather["coord"]["lon"]
            city_max_temp = city_weather["main"]["temp_max"]
            city_humidity = city_weather["main"]["humidity"]
            city_clouds = city_weather["clouds"]["all"]
            city_wind = city_weather["wind"]["speed"]
            city_description = city_weather["weather"][0]["description"]
            # Append the city information into city_data list.
            city_data.append({"City": city.title(),
                              "Country": city_country,
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Current_description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | torbay
# Processing Record 2 of Set 1 | hami
# Processing Record 3 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 1 | russell
# Processing Record 5 of Set 1 | armacao de pera
# Processing Record 6 of Set 1 | nelson bay
# Processing Record 7 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 1 | otane
# Processing Record 9 of Set 1 | nanortalik
# Processing Record 10 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 1 | puerto ayora
# Processing Record 12 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | nikolskoye
# Processing Record 15 of Set 1 | cherskiy
# Processing Record 16 of Set 1 | clarence town
# Processing Record 17 of Set 1 | saskylakh
# Processing Record 18 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 1 | amparai
# City not found. Skipping...
# Processing Record 20 of Set 1 | yellowknife
# Processing Record 21 of Set 1 | bethel
# Processing Record 22 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 1 | tigil
# Processing Record 24 of Set 1 | hilo
# Processing Record 25 of Set 1 | edea
# Processing Record 26 of Set 1 | bredasdorp
# Processing Record 27 of Set 1 | atuona
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | kavieng
# Processing Record 30 of Set 1 | rawson
# Processing Record 31 of Set 1 | hobart
# Processing Record 32 of Set 1 | qaanaaq
# Processing Record 33 of Set 1 | naze
# Processing Record 34 of Set 1 | olafsvik
# Processing Record 35 of Set 1 | livingston
# Processing Record 36 of Set 1 | dujuma
# City not found. Skipping...
# Processing Record 37 of Set 1 | abalak
# Processing Record 38 of Set 1 | kapaa
# Processing Record 39 of Set 1 | kahului
# Processing Record 40 of Set 1 | pangai
# Processing Record 41 of Set 1 | tabulbah
# City not found. Skipping...
# Processing Record 42 of Set 1 | khatanga
# Processing Record 43 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 44 of Set 1 | sao miguel do araguaia
# Processing Record 45 of Set 1 | barrow
# Processing Record 46 of Set 1 | khandyga
# Processing Record 47 of Set 1 | carnarvon
# Processing Record 48 of Set 1 | rikitea
# Processing Record 49 of Set 1 | yeppoon
# Processing Record 50 of Set 1 | aklavik
# Processing Record 1 of Set 2 | zhigansk
# Processing Record 2 of Set 2 | port moresby
# Processing Record 3 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 2 | bocas del toro
# Processing Record 5 of Set 2 | narsaq
# Processing Record 6 of Set 2 | bluff
# Processing Record 7 of Set 2 | pangnirtung
# Processing Record 8 of Set 2 | port hardy
# Processing Record 9 of Set 2 | manacapuru
# Processing Record 10 of Set 2 | akureyri
# Processing Record 11 of Set 2 | saint george
# Processing Record 12 of Set 2 | pleasanton
# Processing Record 13 of Set 2 | abu samrah
# Processing Record 14 of Set 2 | saint-philippe
# Processing Record 15 of Set 2 | meulaboh
# Processing Record 16 of Set 2 | tuatapere
# Processing Record 17 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 2 | jamestown
# Processing Record 19 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 2 | chuy
# Processing Record 21 of Set 2 | manchester
# Processing Record 22 of Set 2 | hualmay
# Processing Record 23 of Set 2 | sioux lookout
# Processing Record 24 of Set 2 | kavaratti
# Processing Record 25 of Set 2 | tasiilaq
# Processing Record 26 of Set 2 | itoman
# Processing Record 27 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 28 of Set 2 | hermanus
# Processing Record 29 of Set 2 | komsomolskiy
# Processing Record 30 of Set 2 | salalah
# Processing Record 31 of Set 2 | ostrovnoy
# Processing Record 32 of Set 2 | kununurra
# Processing Record 33 of Set 2 | umtata
# Processing Record 34 of Set 2 | namibe
# Processing Record 35 of Set 2 | yar-sale
# Processing Record 36 of Set 2 | chara
# Processing Record 37 of Set 2 | deputatskiy
# Processing Record 38 of Set 2 | lompoc
# Processing Record 39 of Set 2 | washougal
# Processing Record 40 of Set 2 | provideniya
# Processing Record 41 of Set 2 | san cristobal
# Processing Record 42 of Set 2 | poplar bluff
# Processing Record 43 of Set 2 | port keats
# Processing Record 44 of Set 2 | bageshwar
# Processing Record 45 of Set 2 | quatre cocos
# Processing Record 46 of Set 2 | mataura
# Processing Record 47 of Set 2 | gallup
# Processing Record 48 of Set 2 | rexburg
# Processing Record 49 of Set 2 | ribeira grande
# Processing Record 50 of Set 2 | bambous virieux
# Processing Record 1 of Set 3 | holzkirchen
# Processing Record 2 of Set 3 | chicama
# Processing Record 3 of Set 3 | east london
# Processing Record 4 of Set 3 | ayabe
# Processing Record 5 of Set 3 | hamilton
# Processing Record 6 of Set 3 | busselton
# Processing Record 7 of Set 3 | kawana waters
# City not found. Skipping...
# Processing Record 8 of Set 3 | bengkulu
# Processing Record 9 of Set 3 | paamiut
# Processing Record 10 of Set 3 | ternate
# Processing Record 11 of Set 3 | cidreira
# Processing Record 12 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 3 | esperance
# Processing Record 14 of Set 3 | new norfolk
# Processing Record 15 of Set 3 | north bend
# Processing Record 16 of Set 3 | batsfjord
# Processing Record 17 of Set 3 | mecca
# Processing Record 18 of Set 3 | albany
# Processing Record 19 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 3 | baykit
# Processing Record 21 of Set 3 | mayumba
# Processing Record 22 of Set 3 | shingu
# Processing Record 23 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 3 | upernavik
# Processing Record 25 of Set 3 | bodden town
# Processing Record 26 of Set 3 | butaritari
# Processing Record 27 of Set 3 | airai
# Processing Record 28 of Set 3 | novorossiysk
# Processing Record 29 of Set 3 | vaini
# Processing Record 30 of Set 3 | kaitangata
# Processing Record 31 of Set 3 | namwala
# Processing Record 32 of Set 3 | punta arenas
# Processing Record 33 of Set 3 | longyearbyen
# Processing Record 34 of Set 3 | atikokan
# Processing Record 35 of Set 3 | careiro da varzea
# Processing Record 36 of Set 3 | arraial do cabo
# Processing Record 37 of Set 3 | nizhnyaya omka
# Processing Record 38 of Set 3 | cap malheureux
# Processing Record 39 of Set 3 | karratha
# Processing Record 40 of Set 3 | fortuna
# Processing Record 41 of Set 3 | yaan
# Processing Record 42 of Set 3 | lorengau
# Processing Record 43 of Set 3 | ancud
# Processing Record 44 of Set 3 | hasaki
# Processing Record 45 of Set 3 | minab
# Processing Record 46 of Set 3 | mehamn
# Processing Record 47 of Set 3 | kalaleh
# Processing Record 48 of Set 3 | byron bay
# Processing Record 49 of Set 3 | buala
# Processing Record 50 of Set 3 | superior
# Processing Record 1 of Set 4 | havre-saint-pierre
# Processing Record 2 of Set 4 | padang
# Processing Record 3 of Set 4 | pevek
# Processing Record 4 of Set 4 | sibolga
# Processing Record 5 of Set 4 | souillac
# Processing Record 6 of Set 4 | kantang
# Processing Record 7 of Set 4 | chapeco
# Processing Record 8 of Set 4 | bathsheba
# Processing Record 9 of Set 4 | avarua
# Processing Record 10 of Set 4 | thompson
# Processing Record 11 of Set 4 | brokopondo
# Processing Record 12 of Set 4 | sumbawa
# City not found. Skipping...
# Processing Record 13 of Set 4 | leningradskiy
# Processing Record 14 of Set 4 | hithadhoo
# Processing Record 15 of Set 4 | abha
# Processing Record 16 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 4 | seymchan
# Processing Record 18 of Set 4 | wanning
# Processing Record 19 of Set 4 | thayetmyo
# Processing Record 20 of Set 4 | kodinsk
# Processing Record 21 of Set 4 | salinopolis
# Processing Record 22 of Set 4 | pacific grove
# Processing Record 23 of Set 4 | tura
# Processing Record 24 of Set 4 | ketchikan
# Processing Record 25 of Set 4 | port elizabeth
# Processing Record 26 of Set 4 | camopi
# Processing Record 27 of Set 4 | kizukuri
# Processing Record 28 of Set 4 | estipona
# Processing Record 29 of Set 4 | kommunar
# Processing Record 30 of Set 4 | manicore
# Processing Record 31 of Set 4 | baghdad
# Processing Record 32 of Set 4 | isiro
# Processing Record 33 of Set 4 | prado
# Processing Record 34 of Set 4 | vila velha
# Processing Record 35 of Set 4 | severnyy
# Processing Record 36 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 4 | axim
# Processing Record 38 of Set 4 | ormara
# Processing Record 39 of Set 4 | faanui
# Processing Record 40 of Set 4 | siavonga
# Processing Record 41 of Set 4 | marsa matruh
# Processing Record 42 of Set 4 | victoria
# Processing Record 43 of Set 4 | los llanos de aridane
# Processing Record 44 of Set 4 | lebu
# Processing Record 45 of Set 4 | leshan
# Processing Record 46 of Set 4 | uusikaupunki
# Processing Record 47 of Set 4 | snasa
# Processing Record 48 of Set 4 | rosario
# Processing Record 49 of Set 4 | vao
# Processing Record 50 of Set 4 | santa marta
# Processing Record 1 of Set 5 | tiksi
# Processing Record 2 of Set 5 | mandalgovi
# Processing Record 3 of Set 5 | bac lieu
# Processing Record 4 of Set 5 | de-kastri
# Processing Record 5 of Set 5 | fairbanks
# Processing Record 6 of Set 5 | hastings
# Processing Record 7 of Set 5 | katsuura
# Processing Record 8 of Set 5 | mahesana
# Processing Record 9 of Set 5 | fort saint john
# City not found. Skipping...
# Processing Record 10 of Set 5 | ostersund
# Processing Record 11 of Set 5 | taltal
# Processing Record 12 of Set 5 | manado
# Processing Record 13 of Set 5 | taoudenni
# Processing Record 14 of Set 5 | umm kaddadah
# Processing Record 15 of Set 5 | miandrivazo
# Processing Record 16 of Set 5 | panguipulli
# Processing Record 17 of Set 5 | lazaro cardenas
# Processing Record 18 of Set 5 | milingimbi
# City not found. Skipping...
# Processing Record 19 of Set 5 | georgetown
# Processing Record 20 of Set 5 | vanimo
# Processing Record 21 of Set 5 | rock falls
# Processing Record 22 of Set 5 | chlorakas
# Processing Record 23 of Set 5 | huarmey
# Processing Record 24 of Set 5 | sao filipe
# Processing Record 25 of Set 5 | caravelas
# Processing Record 26 of Set 5 | joanopolis
# Processing Record 27 of Set 5 | ishigaki
# Processing Record 28 of Set 5 | codrington
# Processing Record 29 of Set 5 | gweta
# Processing Record 30 of Set 5 | castro
# Processing Record 31 of Set 5 | casablanca
# Processing Record 32 of Set 5 | khasan
# Processing Record 33 of Set 5 | port alfred
# Processing Record 34 of Set 5 | san marcos
# Processing Record 35 of Set 5 | kashirskoye
# Processing Record 36 of Set 5 | cimitarra
# Processing Record 37 of Set 5 | port hawkesbury
# Processing Record 38 of Set 5 | guerrero negro
# Processing Record 39 of Set 5 | pecos
# Processing Record 40 of Set 5 | storforshei
# Processing Record 41 of Set 5 | saldanha
# Processing Record 42 of Set 5 | shetpe
# Processing Record 43 of Set 5 | duns
# Processing Record 44 of Set 5 | honiara
# Processing Record 45 of Set 5 | mahibadhoo
# Processing Record 46 of Set 5 | novaya bryan
# Processing Record 47 of Set 5 | winsford
# Processing Record 48 of Set 5 | coahuayana
# Processing Record 49 of Set 5 | carutapera
# Processing Record 50 of Set 5 | kodiak
# Processing Record 1 of Set 6 | nichinan
# Processing Record 2 of Set 6 | burica
# City not found. Skipping...
# Processing Record 3 of Set 6 | napasar
# Processing Record 4 of Set 6 | huilong
# Processing Record 5 of Set 6 | coquimbo
# Processing Record 6 of Set 6 | mpulungu
# Processing Record 7 of Set 6 | krasnoarmeysk
# Processing Record 8 of Set 6 | mahebourg
# Processing Record 9 of Set 6 | qasigiannguit
# Processing Record 10 of Set 6 | bitung
# Processing Record 11 of Set 6 | la serena
# Processing Record 12 of Set 6 | lima
# Processing Record 13 of Set 6 | chalons-en-champagne
# Processing Record 14 of Set 6 | graciano sanchez
# Processing Record 15 of Set 6 | ayan
# Processing Record 16 of Set 6 | kharp
# Processing Record 17 of Set 6 | alyangula
# Processing Record 18 of Set 6 | port blair
# Processing Record 19 of Set 6 | lavrentiya
# Processing Record 20 of Set 6 | anadyr
# Processing Record 21 of Set 6 | bauchi
# Processing Record 22 of Set 6 | ibra
# Processing Record 23 of Set 6 | yulara
# Processing Record 24 of Set 6 | porto novo
# Processing Record 25 of Set 6 | clyde river
# Processing Record 26 of Set 6 | santiago del estero
# Processing Record 27 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 6 | pisco
# Processing Record 29 of Set 6 | singkawang
# Processing Record 30 of Set 6 | mahanoro
# Processing Record 31 of Set 6 | arbazh
# Processing Record 32 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 6 | longonjo
# Processing Record 34 of Set 6 | comodoro rivadavia
# Processing Record 35 of Set 6 | ellensburg
# Processing Record 36 of Set 6 | tymovskoye
# Processing Record 37 of Set 6 | iqaluit
# Processing Record 38 of Set 6 | sinkat
# City not found. Skipping...
# Processing Record 39 of Set 6 | melfort
# Processing Record 40 of Set 6 | eureka
# Processing Record 41 of Set 6 | gravdal
# Processing Record 42 of Set 6 | panguna
# Processing Record 43 of Set 6 | saint-augustin
# Processing Record 44 of Set 6 | tuktoyaktuk
# Processing Record 45 of Set 6 | hoima
# Processing Record 46 of Set 6 | malakal
# Processing Record 47 of Set 6 | wenling
# Processing Record 48 of Set 6 | aksu
# Processing Record 49 of Set 6 | hofn
# Processing Record 50 of Set 6 | verkhnevilyuysk
# Processing Record 1 of Set 7 | sambava
# Processing Record 2 of Set 7 | husavik
# Processing Record 3 of Set 7 | banda aceh
# Processing Record 4 of Set 7 | zherdevka
# Processing Record 5 of Set 7 | chokurdakh
# Processing Record 6 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 7 of Set 7 | chiredzi
# Processing Record 8 of Set 7 | rocha
# Processing Record 9 of Set 7 | flinders
# Processing Record 10 of Set 7 | dalbandin
# Processing Record 11 of Set 7 | robertson
# Processing Record 12 of Set 7 | harbour breton
# Processing Record 13 of Set 7 | barra do corda
# Processing Record 14 of Set 7 | priamurskiy
# Processing Record 15 of Set 7 | poum
# Processing Record 16 of Set 7 | beringovskiy
# Processing Record 17 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 18 of Set 7 | ambulu
# Processing Record 19 of Set 7 | balkanabat
# Processing Record 20 of Set 7 | richards bay
# Processing Record 21 of Set 7 | itupiranga
# Processing Record 22 of Set 7 | tecoanapa
# Processing Record 23 of Set 7 | longavi
# Processing Record 24 of Set 7 | sciacca
# Processing Record 25 of Set 7 | nanticoke
# Processing Record 26 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 7 | santa isabel do rio negro
# Processing Record 28 of Set 7 | mandera
# Processing Record 29 of Set 7 | shizunai
# Processing Record 30 of Set 7 | jumla
# Processing Record 31 of Set 7 | basco
# Processing Record 32 of Set 7 | batagay
# Processing Record 33 of Set 7 | pattoki
# Processing Record 34 of Set 7 | moron
# Processing Record 35 of Set 7 | bulawayo
# Processing Record 36 of Set 7 | teguldet
# Processing Record 37 of Set 7 | aranos
# Processing Record 38 of Set 7 | marystown
# Processing Record 39 of Set 7 | geraldton
# Processing Record 40 of Set 7 | haines junction
# Processing Record 41 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 42 of Set 7 | aswan
# Processing Record 43 of Set 7 | hamburg
# Processing Record 44 of Set 7 | cortez
# Processing Record 45 of Set 7 | ponta do sol
# Processing Record 46 of Set 7 | altamont
# Processing Record 47 of Set 7 | charters towers
# Processing Record 48 of Set 7 | bilma
# Processing Record 49 of Set 7 | inuvik
# Processing Record 50 of Set 7 | sao joao da barra
# Processing Record 1 of Set 8 | maniitsoq
# Processing Record 2 of Set 8 | samarai
# Processing Record 3 of Set 8 | lasa
# Processing Record 4 of Set 8 | henties bay
# Processing Record 5 of Set 8 | labuan
# Processing Record 6 of Set 8 | kudahuvadhoo
# Processing Record 7 of Set 8 | nouakchott
# Processing Record 8 of Set 8 | azul
# Processing Record 9 of Set 8 | santa fe
# Processing Record 10 of Set 8 | kupang
# Processing Record 11 of Set 8 | sarab
# Processing Record 12 of Set 8 | stornoway
# Processing Record 13 of Set 8 | narrabri
# Processing Record 14 of Set 8 | monticello
# Processing Record 15 of Set 8 | tautira
# Processing Record 16 of Set 8 | basar
# Processing Record 17 of Set 8 | litovko
# Processing Record 18 of Set 8 | vestmannaeyjar
# Processing Record 19 of Set 8 | providencia
# Processing Record 20 of Set 8 | fez
# Processing Record 21 of Set 8 | agirish
# Processing Record 22 of Set 8 | tadpatri
# Processing Record 23 of Set 8 | majholi
# Processing Record 24 of Set 8 | general roca
# Processing Record 25 of Set 8 | saint-joseph
# Processing Record 26 of Set 8 | porto santo
# Processing Record 27 of Set 8 | lagoa
# Processing Record 28 of Set 8 | gilgit
# Processing Record 29 of Set 8 | hanna
# Processing Record 30 of Set 8 | buritizeiro
# Processing Record 31 of Set 8 | brownsville
# Processing Record 32 of Set 8 | sawakin
# Processing Record 33 of Set 8 | gedo
# Processing Record 34 of Set 8 | qui nhon
# Processing Record 35 of Set 8 | maltahohe
# Processing Record 36 of Set 8 | auxerre
# Processing Record 37 of Set 8 | panaba
# Processing Record 38 of Set 8 | hoa binh
# Processing Record 39 of Set 8 | waipawa
# Processing Record 40 of Set 8 | dikson
# Processing Record 41 of Set 8 | todos santos
# Processing Record 42 of Set 8 | kultuk
# Processing Record 43 of Set 8 | fort morgan
# Processing Record 44 of Set 8 | belyy yar
# Processing Record 45 of Set 8 | vila franca do campo
# Processing Record 46 of Set 8 | kamenka
# Processing Record 47 of Set 8 | belaya gora
# Processing Record 48 of Set 8 | sorland
# Processing Record 49 of Set 8 | patrasaer
# Processing Record 50 of Set 8 | jesup
# Processing Record 1 of Set 9 | dinghai
# Processing Record 2 of Set 9 | san patricio
# Processing Record 3 of Set 9 | augusta
# Processing Record 4 of Set 9 | luderitz
# Processing Record 5 of Set 9 | sovetskiy
# Processing Record 6 of Set 9 | nantucket
# Processing Record 7 of Set 9 | puerto narino
# Processing Record 8 of Set 9 | jalu
# Processing Record 9 of Set 9 | shawville
# Processing Record 10 of Set 9 | galle
# Processing Record 11 of Set 9 | corrente
# Processing Record 12 of Set 9 | kargasok
# Processing Record 13 of Set 9 | juan lacaze
# Processing Record 14 of Set 9 | birjand
# Processing Record 15 of Set 9 | dekernes
# Processing Record 16 of Set 9 | prainha
# Processing Record 17 of Set 9 | laguna
# Processing Record 18 of Set 9 | mugango
# Processing Record 19 of Set 9 | ho
# City not found. Skipping...
# Processing Record 20 of Set 9 | maumere
# Processing Record 21 of Set 9 | barpathar
# Processing Record 22 of Set 9 | ahmadpur
# Processing Record 23 of Set 9 | san matias
# Processing Record 24 of Set 9 | hambantota
# Processing Record 25 of Set 9 | beidao
# Processing Record 26 of Set 9 | safford
# Processing Record 27 of Set 9 | sangar
# Processing Record 28 of Set 9 | moses lake
# Processing Record 29 of Set 9 | norman wells
# Processing Record 30 of Set 9 | dawlatabad
# Processing Record 31 of Set 9 | sarangani
# Processing Record 32 of Set 9 | naisud
# Processing Record 33 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 34 of Set 9 | madimba
# Processing Record 35 of Set 9 | del rio
# Processing Record 36 of Set 9 | port-cartier
# Processing Record 37 of Set 9 | lodja
# Processing Record 38 of Set 9 | severo-kurilsk
# Processing Record 39 of Set 9 | saint-andre-avellin
# Processing Record 40 of Set 9 | kadykchan
# City not found. Skipping...
# Processing Record 41 of Set 9 | talnakh
# Processing Record 42 of Set 9 | tupelo
# Processing Record 43 of Set 9 | tulum
# Processing Record 44 of Set 9 | westport
# Processing Record 45 of Set 9 | mashhad
# Processing Record 46 of Set 9 | muli
# Processing Record 47 of Set 9 | havoysund
# Processing Record 48 of Set 9 | tukrah
# Processing Record 49 of Set 9 | klyuchi
# Processing Record 50 of Set 9 | mackay
# Processing Record 1 of Set 10 | port-gentil
# Processing Record 2 of Set 10 | champerico
# Processing Record 3 of Set 10 | sept-iles
# Processing Record 4 of Set 10 | mar del plata
# Processing Record 5 of Set 10 | dharchula
# Processing Record 6 of Set 10 | cockburn town
# Processing Record 7 of Set 10 | santarem
# Processing Record 8 of Set 10 | lazurne
# Processing Record 9 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 10 of Set 10 | evensk
# Processing Record 11 of Set 10 | port macquarie
# Processing Record 12 of Set 10 | ilulissat
# Processing Record 13 of Set 10 | gigmoto
# Processing Record 14 of Set 10 | adrar
# Processing Record 15 of Set 10 | ahar
# Processing Record 16 of Set 10 | isangel
# Processing Record 17 of Set 10 | ahipara
# Processing Record 18 of Set 10 | paris
# Processing Record 19 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 20 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 21 of Set 10 | olinda
# Processing Record 22 of Set 10 | kidal
# Processing Record 23 of Set 10 | biltine
# Processing Record 24 of Set 10 | cabo san lucas
# Processing Record 25 of Set 10 | mount gambier
# Processing Record 26 of Set 10 | gat
# Processing Record 27 of Set 10 | natal
# Processing Record 28 of Set 10 | coihaique
# Processing Record 29 of Set 10 | acapulco
# Processing Record 30 of Set 10 | cambrils
# Processing Record 31 of Set 10 | belmonte
# Processing Record 32 of Set 10 | moranbah
# Processing Record 33 of Set 10 | kattivakkam
# Processing Record 34 of Set 10 | kharagpur
# Processing Record 35 of Set 10 | sao sebastiao do paraiso
# Processing Record 36 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 37 of Set 10 | saint anthony
# Processing Record 38 of Set 10 | mount darwin
# Processing Record 39 of Set 10 | muscat
# Processing Record 40 of Set 10 | te anau
# Processing Record 41 of Set 10 | gizo
# Processing Record 42 of Set 10 | medea
# Processing Record 43 of Set 10 | wicklow
# Processing Record 44 of Set 10 | sosnovskoye
# Processing Record 45 of Set 10 | sur
# Processing Record 46 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 47 of Set 10 | thinadhoo
# Processing Record 48 of Set 10 | mendahara
# City not found. Skipping...
# Processing Record 49 of Set 10 | half moon bay
# Processing Record 50 of Set 10 | waingapu
# Processing Record 1 of Set 11 | espanola
# Processing Record 2 of Set 11 | daru
# Processing Record 3 of Set 11 | soyo
# Processing Record 4 of Set 11 | constitucion
# Processing Record 5 of Set 11 | radhanpur
# Processing Record 6 of Set 11 | sibu
# Processing Record 7 of Set 11 | alakurtti
# Processing Record 8 of Set 11 | surt
# Processing Record 9 of Set 11 | yazykovo
# Processing Record 10 of Set 11 | shache
# Processing Record 11 of Set 11 | kruisfontein
# Processing Record 12 of Set 11 | pringsewu
# Processing Record 13 of Set 11 | mildura
# Processing Record 14 of Set 11 | lieksa
# Processing Record 15 of Set 11 | cayenne
# Processing Record 16 of Set 11 | yanchukan
# City not found. Skipping...
# Processing Record 17 of Set 11 | sal rei
# Processing Record 18 of Set 11 | anito
# Processing Record 19 of Set 11 | dudinka
# Processing Record 20 of Set 11 | broome
# Processing Record 21 of Set 11 | tamworth
# Processing Record 22 of Set 11 | sulangan
# Processing Record 23 of Set 11 | bireun
# Processing Record 24 of Set 11 | beloha
# Processing Record 25 of Set 11 | klaksvik
# Processing Record 26 of Set 11 | derzhavinsk
# Processing Record 27 of Set 11 | thoen
# Processing Record 28 of Set 11 | roald
# Processing Record 29 of Set 11 | alofi
# Processing Record 30 of Set 11 | weiser
# Processing Record 31 of Set 11 | phon
# Processing Record 32 of Set 11 | tanabe
# Processing Record 33 of Set 11 | rubizhne
# Processing Record 34 of Set 11 | portland
# Processing Record 35 of Set 11 | fagaras
# Processing Record 36 of Set 11 | atambua
# Processing Record 37 of Set 11 | nizhniy baskunchak
# Processing Record 38 of Set 11 | tevriz
# Processing Record 39 of Set 11 | dawei
# Processing Record 40 of Set 11 | havelock
# Processing Record 41 of Set 11 | bani
# Processing Record 42 of Set 11 | bose
# Processing Record 43 of Set 11 | atherton
# Processing Record 44 of Set 11 | muzhi
# Processing Record 45 of Set 11 | bubaque
# Processing Record 46 of Set 11 | naples
# Processing Record 47 of Set 11 | mamallapuram
# Processing Record 48 of Set 11 | kutum
# Processing Record 49 of Set 11 | ustye
# Processing Record 50 of Set 11 | santa cruz
# Processing Record 1 of Set 12 | vestnes
# Processing Record 2 of Set 12 | pasan
# Processing Record 3 of Set 12 | moindou
# Processing Record 4 of Set 12 | san rafael
# Processing Record 5 of Set 12 | loreto
# Processing Record 6 of Set 12 | labrea
# Processing Record 7 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 8 of Set 12 | ulladulla
# Processing Record 9 of Set 12 | kailua
# Processing Record 10 of Set 12 | nanzhang
# Processing Record 11 of Set 12 | xai-xai
# Processing Record 12 of Set 12 | nome
# Processing Record 13 of Set 12 | rampura
# Processing Record 14 of Set 12 | melito di porto salvo
# Processing Record 15 of Set 12 | bakchar
# Processing Record 16 of Set 12 | baicheng
# Processing Record 17 of Set 12 | annau
# Processing Record 18 of Set 12 | conde
# Processing Record 19 of Set 12 | wattegama
# Processing Record 20 of Set 12 | yeniseysk
# Processing Record 21 of Set 12 | piedras negras
# Processing Record 22 of Set 12 | gikongoro
# Processing Record 23 of Set 12 | maryville
# Processing Record 24 of Set 12 | visnes
# Processing Record 25 of Set 12 | makaha
# Processing Record 26 of Set 12 | itarema
# Processing Record 27 of Set 12 | taga
# Processing Record 28 of Set 12 | muros
# Processing Record 29 of Set 12 | merauke
# Processing Record 30 of Set 12 | grand gaube
# Processing Record 31 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 32 of Set 12 | dingle
# Processing Record 33 of Set 12 | kozhva
# Processing Record 34 of Set 12 | la asuncion
# Processing Record 35 of Set 12 | shimoda
# Processing Record 36 of Set 12 | guia de isora
# Processing Record 37 of Set 12 | srandakan
# Processing Record 38 of Set 12 | brae
# Processing Record 39 of Set 12 | gondanglegi
# Processing Record 40 of Set 12 | vertou
# Processing Record 41 of Set 12 | chaochou
# City not found. Skipping...
# Processing Record 42 of Set 12 | pastavy
# Processing Record 43 of Set 12 | nerchinskiy zavod
# Processing Record 44 of Set 12 | ugoofaaru
# Processing Record 45 of Set 12 | kathu
# Processing Record 46 of Set 12 | ballina
# Processing Record 47 of Set 12 | moose factory
# Processing Record 48 of Set 12 | floro
# Processing Record 49 of Set 12 | hefei
# Processing Record 50 of Set 12 | mareeba
# Processing Record 1 of Set 13 | zhangye
# Processing Record 2 of Set 13 | nshamba
# Processing Record 3 of Set 13 | colares
# Processing Record 4 of Set 13 | omboue
# Processing Record 5 of Set 13 | punto fijo
# Processing Record 6 of Set 13 | popondetta
# Processing Record 7 of Set 13 | tomatlan
# Processing Record 8 of Set 13 | hit
# Processing Record 9 of Set 13 | tungkang
# City not found. Skipping...
# Processing Record 10 of Set 13 | scottsburgh
# City not found. Skipping...
# Processing Record 11 of Set 13 | yingshang
# City not found. Skipping...
# Processing Record 12 of Set 13 | huatusco
# Processing Record 13 of Set 13 | talcahuano
# Processing Record 14 of Set 13 | dunedin
# Processing Record 15 of Set 13 | camacha
# Processing Record 16 of Set 13 | harper
# Processing Record 17 of Set 13 | egvekinot
# Processing Record 18 of Set 13 | taloqan
# Processing Record 19 of Set 13 | edd
# Processing Record 20 of Set 13 | berlevag
# Processing Record 21 of Set 13 | sidi ali
# Processing Record 22 of Set 13 | canon city
# Processing Record 23 of Set 13 | marica
# Processing Record 24 of Set 13 | acajutiba
# Processing Record 25 of Set 13 | awjilah
# Processing Record 26 of Set 13 | ust-kuyga
# Processing Record 27 of Set 13 | balkhash
# Processing Record 28 of Set 13 | penzance
# Processing Record 29 of Set 13 | mokhsogollokh
# Processing Record 30 of Set 13 | ixtapa
# Processing Record 31 of Set 13 | touros
# Processing Record 32 of Set 13 | asadabad
# Processing Record 33 of Set 13 | seoul
# Processing Record 34 of Set 13 | fort nelson
# Processing Record 35 of Set 13 | ardesen
# Processing Record 36 of Set 13 | la rioja
# Processing Record 37 of Set 13 | sellye
# Processing Record 38 of Set 13 | andros town
# Processing Record 39 of Set 13 | tombouctou
# Processing Record 40 of Set 13 | barra do bugres
# Processing Record 41 of Set 13 | srednekolymsk
# Processing Record 42 of Set 13 | mamakan
# Processing Record 43 of Set 13 | novo aripuana
# Processing Record 44 of Set 13 | kataysk
# Processing Record 45 of Set 13 | ayagoz
# Processing Record 46 of Set 13 | jatoi
# City not found. Skipping...
# Processing Record 47 of Set 13 | skagastrond
# City not found. Skipping...
# Processing Record 48 of Set 13 | moissala
# Processing Record 49 of Set 13 | yambio
# Processing Record 50 of Set 13 | chimbote
# Processing Record 1 of Set 14 | roanoke rapids
# Processing Record 2 of Set 14 | yuci
# Processing Record 3 of Set 14 | dwarka
# Processing Record 4 of Set 14 | gewane
# Processing Record 5 of Set 14 | zhigalovo
# Processing Record 6 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 14 | goderich
# Processing Record 8 of Set 14 | mayo
# Processing Record 9 of Set 14 | sigli
# Processing Record 10 of Set 14 | magadan
# Processing Record 11 of Set 14 | verkhneyarkeyevo
# Processing Record 12 of Set 14 | buraydah
# Processing Record 13 of Set 14 | parainen
# Processing Record 14 of Set 14 | port hedland
# Processing Record 15 of Set 14 | muisne
# Processing Record 16 of Set 14 | kieta
# Processing Record 17 of Set 14 | bhatkal
# Processing Record 18 of Set 14 | renqiu
# Processing Record 19 of Set 14 | keti bandar
# Processing Record 20 of Set 14 | taebla
# Processing Record 21 of Set 14 | sampit
# Processing Record 22 of Set 14 | walvis bay
# Processing Record 23 of Set 14 | tres lagoas
# Processing Record 24 of Set 14 | faya
# Processing Record 25 of Set 14 | jiblah
# Processing Record 26 of Set 14 | yanam
# Processing Record 27 of Set 14 | erdaojiang
# Processing Record 28 of Set 14 | hokitika
# Processing Record 29 of Set 14 | moerai
# Processing Record 30 of Set 14 | les cayes
# Processing Record 31 of Set 14 | mitsamiouli
# Processing Record 32 of Set 14 | flin flon
# Processing Record 33 of Set 14 | puerto boyaca
# Processing Record 34 of Set 14 | solnechnyy
# Processing Record 35 of Set 14 | kasongo-lunda
# Processing Record 36 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 37 of Set 14 | bemidji
# Processing Record 38 of Set 14 | porto velho
# Processing Record 39 of Set 14 | bandarbeyla
# Processing Record 40 of Set 14 | duz
# City not found. Skipping...
# Processing Record 41 of Set 14 | pascagoula
# Processing Record 42 of Set 14 | boguchany
# Processing Record 43 of Set 14 | cerqueira cesar
# Processing Record 44 of Set 14 | domoni
# Processing Record 45 of Set 14 | ilek
# Processing Record 46 of Set 14 | ati
# Processing Record 47 of Set 14 | oranjestad
# Processing Record 48 of Set 14 | tagusao
# Processing Record 49 of Set 14 | baoro
# Processing Record 50 of Set 14 | danville
# Processing Record 1 of Set 15 | camana
# Processing Record 2 of Set 15 | sola
# Processing Record 3 of Set 15 | namatanai
# Processing Record 4 of Set 15 | ust-nera
# Processing Record 5 of Set 15 | wageningen
# Processing Record 6 of Set 15 | sitka
# Processing Record 7 of Set 15 | smidovich
# Processing Record 8 of Set 15 | talara
# Processing Record 9 of Set 15 | nishihara
# Processing Record 10 of Set 15 | nanakuli
# Processing Record 11 of Set 15 | port lincoln
# Processing Record 12 of Set 15 | mantamados
# Processing Record 13 of Set 15 | warri
# Processing Record 14 of Set 15 | prince rupert
# Processing Record 15 of Set 15 | asau
# Processing Record 16 of Set 15 | jaque
# Processing Record 17 of Set 15 | saint-marc-des-carrieres
# Processing Record 18 of Set 15 | la romana
# Processing Record 19 of Set 15 | nouadhibou
# Processing Record 20 of Set 15 | adelanto
# Processing Record 21 of Set 15 | tooele
# Processing Record 22 of Set 15 | kundiawa
# Processing Record 23 of Set 15 | ibotirama
# Processing Record 24 of Set 15 | imbituba
# Processing Record 25 of Set 15 | suna
# Processing Record 26 of Set 15 | corinto
# Processing Record 27 of Set 15 | talaya
# Processing Record 28 of Set 15 | makat
# Processing Record 29 of Set 15 | asfi
# Processing Record 30 of Set 15 | majene
# Processing Record 31 of Set 15 | kautokeino
# Processing Record 32 of Set 15 | catamarca
# Processing Record 33 of Set 15 | southbridge
# Processing Record 34 of Set 15 | la ligua
# Processing Record 35 of Set 15 | toora-khem
# Processing Record 36 of Set 15 | cerrito
# Processing Record 37 of Set 15 | kegayli
# City not found. Skipping...
# Processing Record 38 of Set 15 | fare
# Processing Record 39 of Set 15 | saquarema
# Processing Record 40 of Set 15 | juneau
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Torbay      CA  47.6666  -52.7314     70.57        60          75
# 1             Hami      CN  42.8000   93.4500     89.62        17           2
# 2          Russell      US  32.3502  -85.1999     92.48        55          20
# 3  Armacao De Pera      PT  37.1026   -8.3570     89.51        60           0
# 4       Nelson Bay      AU -32.7167  152.1500     48.69        93           0
# 5            Otane      NZ -39.8833  176.6333     44.38        96           7
# 6       Nanortalik      GL  60.1432  -45.2371     48.45        71         100
# 7     Puerto Ayora      EC  -0.7393  -90.3518     75.16        90          57
# 8          Ushuaia      AR -54.8000  -68.3000     38.82        87          75
# 9       Nikolskoye      RU  59.7035   30.7861     67.78        67          17
#
#    Wind Speed Current_description
# 0       17.27       broken clouds
# 1       32.99           clear sky
# 2        3.44          few clouds
# 3       15.97           clear sky
# 4        4.90           clear sky
# 5        0.76           clear sky
# 6       11.12     overcast clouds
# 7       11.01       broken clouds
# 8       21.85       broken clouds
# 9        5.55          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# %%
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
